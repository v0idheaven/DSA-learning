# %% [markdown]
# **Using Loop**

# %%
num = 5873
count = 0
while num > 0:
    count+=1
    num = num//10
print(count)

# %% [markdown]
# **Using Log**

# %%
num = 5873
from math import log10
def digit_count(num):
    return int(log10(num)) + 1
print(digit_count(num))

# %%
num = 153
count = 0
total = 0
while num > 0:
    count+=1
    num = num//10

while num > 0:
    ld = num % 10
    total += ld ** count
    num = num // 10

print(num == total)

# %%
num = 153
count = 0
total = 0
while num > 0:
    count+=1
    num = num//10

while num > 0:
    ld = num % 10
    total += ld ** count
    num = num // 10

print(num == total)
# Out:
# True
